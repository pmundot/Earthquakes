# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import scipy as sci
from requests import get

# %%
past=pd.read_excel('Earthquake raw data.xlsx')

# %%
lister=['Country (Epicenter)','Mw/ ML', 'Depth (km)','Intensity (MMI / JMA)','Fatalities','Injuries','displaced','buildings damaged','buildings destroyed','Financial losses ($)']
Raw=past[lister]
test=Raw

# %%
lister=['Country (Epicenter)','Mw/ ML', 'Depth (km)','Fatalities','Injuries','displaced','buildings damaged','buildings destroyed','Financial losses ($)']
def conversion(title,column):
    title[column]=title[column].str.replace(',','.')
    title[column]=title[column].str.replace('#',' ')
    #title[column]=title[column].str.strip('/')
    title[column]=title[column].fillna(0)
    title[column]=pd.to_numeric(title[column])
    return(title)

def where(title,column):
    return (title[pd.to_numeric(title[column], errors='coerce').isnull()])

where(test,'buildings damaged')
# Out:
#     Country (Epicenter) Mw/ ML Depth (km) Intensity (MMI / JMA) Fatalities  \
# 34               Poland    4.6          1                   NaN          0
# 112               India    5.9         14                   VII          0
# 114    Papua New Guinea    7.2        127                   VII          0
# 142               China    5.4         10                   NaN          0
# 146           Indonesia    7.3        208                   NaN          0
# 149              #Sudan    NaN        NaN                   NaN        #12
# 155               China    5.6          8                   NaN          0
# 156                 USA    6.4         11                   NaN          0
# 206              Poland    4.1          1                   NaN          0
# 220               India    NaN        NaN                   NaN          0
# 222                Iran    4,4         10                   NaN          0
# ...

# %%
pab=test.loc[[601]]
for i in range(1,len(lister)-1):
    pab[lister[i]]=pab[lister[i]].str.strip('/')
pab
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-8f73401dad91> in <module>
#       1 pab=test.loc[[601]]
#       2 for i in range(1,len(lister)-1):
# ----> 3     pab[lister[i]]=pab[lister[i]].str.strip('/')
#       4 pab
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
# ...

# %%
Raw
# Out:
#     Country (Epicenter) Mw/ ML Depth (km) Intensity (MMI / JMA) Fatalities  \
# 0                 Italy    4.1         17                     V          0
# 1                Mexico    4.2          5                   NaN          0
# 2                 China    5.3         15                   VII          0
# 3                 Japan    5.0         10                    6-          0
# 4               Albania    4.8         28                   NaN          0
# ..                  ...    ...        ...                   ...        ...
# 732               Italy    4.9          1                  VIII          0
# 733           Venezuela    5.5         10                  VII         NaN
# 734           Indonesia    5.7         41                   NaN          0
# 735              Mexico    4.2        NaN                   NaN        NaN
# 736            Thailand    4.9        NaN                   NaN          0
#
#     Injuries displaced buildings damaged buildings destroyed  \
# ...

# %%
a = "/4600"
b = a.strip("/")
print (b)
# Out:
# 4600
